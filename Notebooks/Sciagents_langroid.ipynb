# %%
import os

# ============= 设置 OpenAI 与 PubMed API 密钥 =============
OpenAI_key=''

os.environ['OPENAI_API_KEY'] = OpenAI_key

# PubMed e-utilities 基础 URL
PUBMED_URL = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
PUBMED_FETCH_URL = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi"
# PubMed API Key
PubMed_api_key = ""
os.environ["PUBMED_API_KEY"] = PubMed_api_key

# %%
import sys
sys.path.insert(0, r"D:\DFKI\SciAgentsDiscovery-openai\SciAgentsDiscovery-main")

# 假设你将改写后的文件命名为 agents_new_langroid.py
from ScienceDiscovery.agents_langroid import run_chat

# %%
result = run_chat("Based on the relationship between TP53, BRCA1 and PARP1, please generate assumptions.")
print(result)
# Out:
# WARNING:langroid.cachedb.redis_cachedb:REDIS_PASSWORD, REDIS_HOST, REDIS_PORT not set in .env file,
#                         using fake redis client
# 2025-03-13 19:18:27 - WARNING - REDIS_PASSWORD, REDIS_HOST, REDIS_PORT not set in .env file,
#                         using fake redis client
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# **Execution Plan for Generating Hypotheses about 'BRCA1'**
#
# **Step 1: Retrieve a KG summary from Neo4j (via DiseaseExplorerAgent)**
# - Task: Query the Neo4j database to obtain a knowledge graph (KG) summary specifically related to BRCA1, which may include information on its biological functions, associated diseases, related genes, and known interactions.
# - Action: Initiate a request to the DiseaseExplorerAgent to fetch the relevant KG summary.
#
# ...
